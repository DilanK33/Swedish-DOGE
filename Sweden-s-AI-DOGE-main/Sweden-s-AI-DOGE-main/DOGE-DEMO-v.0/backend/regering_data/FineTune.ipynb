# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("DOGE DEMO.csv")
df.head()
# Out:
#      År Myndighet                                        Anslagsnamn  \
# 0  2022       NaN  Ålderspensionssystemet vid sidan av statens bu...
# 1  2022       NaN  Ålderspensionssystemet vid sidan av statens bu...
# 2  2022       NaN  Ålderspensionssystemet vid sidan av statens bu...
# 3  2022       NaN  Ålderspensionssystemet vid sidan av statens bu...
# 4  2022       NaN  Ålderspensionssystemet vid sidan av statens bu...
#
#                 Anslagspostsnamn  \
# 0  AP-fonderna, pensionsutgifter
# 1        Administrationsutgifter
# 2  AP-fonderna, pensionsutgifter
# 3        Administrationsutgifter
# 4        Administrationsutgifter
#
#                                   Utgiftsområdesnamn  Organisationsnummer  \
# 0  Ålderspensionssystemet vid sidan av statens bu...                  NaN
# 1  Ålderspensionssystemet vid sidan av statens bu...                  NaN
# 2  Ålderspensionssystemet vid sidan av statens bu...                  NaN
# ...

# %%
df.drop(["Unnamed: 7", "Unnamed: 8"], axis=1, inplace=True)

# %%
df
# Out:
#         År         Myndighet  \
# 0     2022               NaN
# 1     2022               NaN
# 2     2022               NaN
# 3     2022               NaN
# 4     2022               NaN
# ...    ...               ...
# 4103  2024   Kammarkollegiet
# 4104  2024   Kammarkollegiet
# 4105  2024  Naturvårdsverket
# 4106  2024        Tullverket
# 4107  2024      Skatteverket
#
#                                             Anslagsnamn  \
# 0     Ålderspensionssystemet vid sidan av statens bu...
# 1     Ålderspensionssystemet vid sidan av statens bu...
# 2     Ålderspensionssystemet vid sidan av statens bu...
# 3     Ålderspensionssystemet vid sidan av statens bu...
# 4     Ålderspensionssystemet vid sidan av statens bu...
# ...                                                 ...
# 4103          Återställning av Riksbankens eget kapital
# 4104                   Avgiften till Europeiska unionen
# 4105                   Avgiften till Europeiska unionen
# ...

# %%
df.to_csv("output_demo_v1", index=False)
