# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\dilan\OneDrive\Desktop\regering_data\Månadsutfall utgifter januari 2006 - december 2024, preliminärt.csv", sep=";")
filtered_df = df[df['År'] >= 2022]
filtered_df
# Out:
#        Utgiftsområde                                 Utgiftsområdesnamn  \
# 20070            NaN  Ålderspensionssystemet vid sidan av statens bu...
# 20071            NaN  Ålderspensionssystemet vid sidan av statens bu...
# 20072            NaN  Ålderspensionssystemet vid sidan av statens bu...
# 20073            NaN  Ålderspensionssystemet vid sidan av statens bu...
# 20074            NaN  Ålderspensionssystemet vid sidan av statens bu...
# ...              ...                                                ...
# 24173           26.0                             Statsskuldsräntor m.m.
# 24174           27.0                   Avgiften till Europeiska unionen
# 24175           27.0                   Avgiften till Europeiska unionen
# 24176           27.0                   Avgiften till Europeiska unionen
# 24177           27.0                   Avgiften till Europeiska unionen
#
#         Anslag                                        Anslagsnamn  \
# ...

# %%
filtered_df.drop(columns=["Utgiftsområdesnamn", "Anslagsdelpost", "Anslagsdelpostsnamn", "Utgiftsområde utfallsår", "Anslag utfallsår", "Anslagsnamn utfallsår", "Anslagspost utfallsår", "Anslagspostsnamn utfallsår", "Anslagsdelpost utfallsår", "Anslagsdelpostsnamn utfallsår"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 filtered_df.drop(columns=["Utgiftsområdesnamn", "Anslagsdelpost", "Anslagsdelpostsnamn", "Utgiftsområde utfallsår", "Anslag utfallsår", "Anslagsnamn utfallsår", "Anslagspost utfallsår", "Anslagspostsnamn utfallsår", "Anslagsdelpost utfallsår", "Anslagsdelpostsnamn utfallsår"])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
# ...

# %%
filtered_df.drop(columns=["Utgiftsområdesnamn", "Anslagsdelpost", "Anslagsdelpostsnamn", "Utgiftsområde utfallsår", "Anslag utfallsår", "Anslagsnamn utfallsår", "Anslagspost utfallsår", "Anslagspostsnamn utfallsår", "Anslagsdelpost utfallsår", "Anslagsdelpostsnamn utfallsår"], inplace=True)
# Out:
# C:\Users\dilan\AppData\Local\Temp\ipykernel_11160\4133418710.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop(columns=["Utgiftsområdesnamn", "Anslagsdelpost", "Anslagsdelpostsnamn", "Utgiftsområde utfallsår", "Anslag utfallsår", "Anslagsnamn utfallsår", "Anslagspost utfallsår", "Anslagspostsnamn utfallsår", "Anslagsdelpost utfallsår", "Anslagsdelpostsnamn utfallsår"], inplace=True)

# %%
filtered_df.drop(columns=["Utgiftsområdesnamn utfallsår"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 filtered_df.drop(columns=["Utgiftsområdesnamn utfallsår"], inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
filtered_df = filtered_df.set_index('År')

# %%
filtered_df
# Out:
#       Utgiftsområde   Anslag  \
# År
# 2022            NaN      NaN
# 2022            NaN      NaN
# 2022            NaN      NaN
# 2022            NaN      NaN
# 2022            NaN      NaN
# ...             ...      ...
# 2024           26.0  2602001
# 2024           27.0  2701001
# 2024           27.0  2701001
# 2024           27.0  2701001
# 2024           27.0  2701001
#
#                                             Anslagsnamn  Anslagspost  \
# År
# 2022  Ålderspensionssystemet vid sidan av statens bu...          NaN
# 2022  Ålderspensionssystemet vid sidan av statens bu...          NaN
# 2022  Ålderspensionssystemet vid sidan av statens bu...          NaN
# 2022  Ålderspensionssystemet vid sidan av statens bu...          NaN
# 2022  Ålderspensionssystemet vid sidan av statens bu...          NaN
# ...                                                 ...          ...
# 2024          Återställning av Riksbankens eget kapital          1.0
# ...
